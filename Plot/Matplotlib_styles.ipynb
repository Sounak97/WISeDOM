# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['dark_background',
#  'classic',
#  'tableau-colorblind10',
#  'seaborn-bright',
#  'seaborn-deep',
#  'bmh',
#  'Solarize_Light2',
#  'seaborn-muted',
#  'fivethirtyeight',
#  'seaborn-poster',
#  'seaborn-dark',
#  'seaborn-colorblind',
#  'seaborn-notebook',
#  'seaborn-dark-palette',
#  'fast',
#  'seaborn-pastel',
#  'seaborn-white',
#  'ggplot',
#  'seaborn',
#  'seaborn-ticks',
#  'seaborn-whitegrid',
#  'seaborn-talk',
#  'seaborn-darkgrid',
#  '_classic_test',
#  'seaborn-paper',
#  'grayscale']

# %%
x1_values = [2012, 2013, 2014, 2015]
y1_values = [4.3, 2.5, 3.5, 4.5]

x2_values = [2012, 2013, 2014, 2015]
y2_values = [2.4, 4.4, 1.8, 2.8]

x3_values = [2012, 2013, 2014, 2015]
y3_values = [2, 2, 3, 5]

# %%
with plt.style.context('fivethirtyeight'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='Java')
    plt.plot(x3_values, y3_values, label='C++')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

# %%
with plt.style.context('bmh'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

# %%
with plt.style.context('fivethirtyeight'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

# %%
#Explore, to create cust
